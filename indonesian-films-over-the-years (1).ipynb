# %% [markdown]
# # 1. Introduction

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Data Loading & Cleaning

# %%
df = pd.read_csv('indonesian_movies.csv')
df.head()
# Out:
#    movie_id                     title  year  \
# 0    100001       #FriendButMarried 2  2020
# 1    100002                  4 Mantan  2020
# 2    100003  Aku Tahu Kapan Kamu Mati  2020
# 3    100004               Anak Garuda  2020
# 4    100005                 Dignitate  2020
#
#                                          description      genre rating  \
# 0  Ayudia (Mawar De Jongh) is not satisfied enoug...  Biography    13+
# 1  Sara, Airin, Rachel, and Amara were accidental...   Thriller    17+
# 2  After apparent death, Siena is able to see sig...     Horror    13+
# 3  Good Morning Indonesia, a school for poor orph...  Adventure    13+
# 4  Alfi (Al Ghazali) meets Alana (Caitlin Halderm...      Drama    17+
#
#    users_rating votes   languages          directors  \
# 0           6.5   120  Indonesian      Rako Prijanto
# 1           6.4     8  Indonesian      Hanny Saputra
# 2           5.4    17  Indonesian  Hadrah Daeng Ratu
# 3           9.1    27  Indonesian       Faozan Rizal
# 4           7.6    33  Indonesian       Fajar Nugros
#
#                                               actors  runtime
# 0  ['Adipati Dolken', 'Mawar Eva de Jongh', 'Vonn...  100 min
# 1  ['Ranty Maria', 'Jeff Smith', 'Melanie Berentz...   80 min
# 2  ['Natasha Wilona', 'Ria Ricis', 'Al Ghazali', ...   92 min
# 3  ['Tissa Biani Azzahra', 'Violla Georgie', 'Aji...  129 min
# 4  ['Al Ghazali', 'Caitlin Halderman', 'Giorgino ...  109 min

# %%
print(df.info(),'\n\n')

print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      1272 non-null   int64
#  1   title         1272 non-null   object
#  2   year          1272 non-null   int64
#  3   description   840 non-null    object
#  4   genre         1236 non-null   object
#  5   rating        376 non-null    object
#  6   users_rating  1272 non-null   float64
#  7   votes         1272 non-null   object
#  8   languages     1272 non-null   object
#  9   directors     1265 non-null   object
#  10  actors        1272 non-null   object
#  11  runtime       869 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 119.4+ KB
# None
#
#
# movie_id          0
# title             0
# year              0
# description     432
# genre            36
# rating          896
# users_rating      0
# votes             0
# languages         0
# directors         7
# actors            0
# runtime         403
# dtype: int64

# %%
df.votes                = df.votes.apply(lambda x: x.replace(',','')).astype('int')
df.actors               = df.actors.apply(lambda x: x[1:-1].replace("'","").split(', '))
df.runtime              = df.runtime.str.replace(r'\D', '').astype('float')
df.movie_id             = df.movie_id.astype('category')

# %%
lis=[]
for i in range(1272):
    if df["year"][i] > 2010:
        lis.append('2010-2020')
    elif df["year"][i] <= 2010 and df["year"][i] > 2000:
        lis.append('2000-2010')
    elif df["year"][i] <= 2000 and df["year"][i] > 1990:
        lis.append('1990-2000')
    elif df["year"][i] <= 1990 and df["year"][i] > 1980:
        lis.append('1980-1990')
    elif df["year"][i] <= 1980 and df["year"][i] > 1970:
        lis.append('1970-1980')
    elif df["year"][i] <= 1970 and df["year"][i] > 1960:
        lis.append('1960-1970')
    elif df["year"][i] <= 1960 and df["year"][i] > 1950:
        lis.append('1950-1960')
    else:
        lis.append('<1950')
df['decade'] = lis

# %% [markdown]
# - Changing the 'votes' and 'runtime' data type as numerical type to enabling EDA
# - Changing the 'actor' data type into list by splitting the string type values for later analysis
# - Adding 'decade' variable to classify the movies into a more relevant timeline

# %%
#fill the 'nan' value in variable 'directors'
df.directors[137] = str(df.directors[137]).replace('nan','Amar Mukhi')
df.directors[222] = str(df.directors[222]).replace('nan','Tema Patrosza')
df.directors[426] = str(df.directors[426]).replace('nan','Indra Gunawan')
df.directors[1022] = str(df.directors[1022]).replace('nan','Steady Rimba')
df.directors[1046] = str(df.directors[1046]).replace('nan','S.A. Karim')
df.directors[1255] = str(df.directors[1255]).replace('nan','AN Alcaff')
df.directors[1270] = str(df.directors[1270]).replace('nan','Joshua Wong')

# %%
#fill the 'nan' values of variable 'runtime'
df['runtime']=df['runtime'].fillna(df.groupby(['decade'])['runtime'].transform('mean'))
df['runtime'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - There are some columns of the Data consist of null values such as description, genre, rating, directors, and runtime column.
# - The 'directors' column consist of the least number of null values, and we feel like we can fill it with some information gathered from the internet, so we do it.
# - Because the 'runtime' column consists with numerical value, We can fill it with the mean of movies. For each null value, we calculated the mean with every movies in particular decade represents the movie, because we thought that the average of film runtimes is changing over the decades.
# - The rest of column with null values are ignored for now, because they consist a non numerical values.

# %% [markdown]
# From a quick describe of the data, we learn that:
#  - The data are about Indonesian movies made over the years of 1926 - 2020.
#  - From the 'year' variable, the median is 2011. It means the data distributed more to the latter year.<br>
#
# We can further run the Exploratory Data Analysis and look for:
#  - Most movie genres ever been made over the years
#  - Best movies based on users rating
#  - Most active Actors who played in the most movies

# %% [markdown]
# # 3. Basic Description

# %%
df_g                = df.groupby(['genre']).size().reset_index()
df_g ['percentage'] = df.groupby(['genre']).size().apply(lambda x: 100*x/ df.groupby(['genre']).size().sum()).values
df_g.columns        = ['genre','counts','percentage']
fig                 = px.bar (df_g, 
                              x='genre',
                              y = 'counts',
                              color='genre',
                              text=df_g['percentage'].apply(lambda x: '{0:1.2f}%'.format(x)),
                              title= 'Indonesian Movies by Genre')
fig.show()


df_g                = df.groupby(['decade']).size().reset_index()
df_g ['percentage'] = df.groupby(['decade']).size().apply(lambda x: 100*x/ df.groupby(['decade']).size().sum()).values
df_g.columns        = ['decade','counts','percentage']
fig                 = px.bar (df_g, 
                              x = df_g['decade'],
                              y = 'counts',
                              color='decade',
                              text=df_g['percentage'].apply(lambda x: '{0:1.2f}%'.format(x)),
                              title= 'Indonesian Movies by Decade')
fig.update_xaxes(categoryorder='array', categoryarray= ['<1950','1950-1960','1960-1970','1970-1980','1980-1990','1990-2000','2000-2010','2010-2020'])
fig.show()

# %% [markdown]
# # 4. Exploratory Data Analysis
# From the EDA we found that :
# - First Indonesian Movie that been made was a Fantasy movie called 'Loetoeng Kasarung' by L. Heuveldorp back in 1926.
# - Indonesian movies are dominated by the genre of 'Drama'.
# - Indonesian Movies have been produced most at the 2010s.

# %%
df.describe()
# Out:
#               year  users_rating          votes      runtime
# count  1272.000000   1272.000000    1272.000000  1272.000000
# mean   2007.023585      6.144418     459.427673    96.895518
# std      12.968560      1.389315    6288.883170    13.479680
# min    1926.000000      1.200000       5.000000    45.000000
# 25%    2006.000000      5.300000      12.000000    90.000000
# 50%    2011.000000      6.400000      27.000000    97.113861
# 75%    2016.000000      7.100000      76.000000   100.000000
# max    2020.000000      9.400000  187222.000000   262.000000

# %%
df.sort_values(by='year').head()
# Out:
#      movie_id                  title  year  \
# 1271   101272     Loetoeng Kasaroeng  1926
# 1270   101271      Resia Boroboedoer  1928
# 1269   101270          Darah dan Doa  1950
# 1268   101269    Enam Djam di Djogja  1951
# 1267   101268  The Tiger from Tjampa  1953
#
#                                             description      genre rating  \
# 1271                                                NaN    Fantasy    NaN
# 1270                                                NaN  Adventure    NaN
# 1269  It tells the story of an Indonesian revolution...      Drama    NaN
# 1268  Depicting the celebrated recapture of the town...      Drama    NaN
# 1267  Set in the 1930s, and narrated like a ballad f...      Drama    NaN
#
#       users_rating  votes   languages       directors  \
# 1271           7.2     11  Indonesian   L. Heuveldorp
# 1270           7.0      8  Indonesian     Joshua Wong
# 1269           6.6     27  Indonesian    Usmar Ismail
# 1268           6.3      9  Indonesian    Usmar Ismail
# 1267           6.4     30  Indonesian  D. Djajakusuma
#
#                                                  actors  runtime     decade
# 1271  [Martoana, Oemar, nan, nan, nan, nan, nan, nan...     60.0      <1950
# 1270  [Olive Young, nan, nan, nan, nan, nan, nan, na...    105.0      <1950
# 1269  [Ella Bergen, Faridah, R.D. Ismail, Del Juzar,...    150.0      <1950
# 1268  [R.D. Ismail, Del Juzar, Aedy Moward, Agus Mul...    116.0  1950-1960
# 1267  [Wahid Chan, Bambang Hermanto, R.D. Ismail, Ma...     97.0  1950-1960

# %% [markdown]
# ## Top 5 Indonesian movies
# We calculate the top 5 Indonesian Movies by The formula for calculating the Top Rated 250
# by IMDB: http://www.imdb.com/chart/top <br>
#
# with a True Bayesian estimate Formula:
# weighted rating (WR) = (v ÷ (v+m)) × R + (m ÷ (v+m)) × C where:
#
# - R = average user rating for the movie = (user_rating)
# - v = number of votes for the movie = (votes)
# - m = minimum votes required to be listed in the Top 250
# - C = the mean user rating across the whole report <br>
#
# The minimum votes required (m) is determined by the 0.75 quantile 'votes' number for every movie in the data (76). The mean user rating across the whole data (C) is calculated by sum of ['rating'] * ['votes'] given for every movies across the whole data divided by the sum of votes participated across the whole data.

# %%
print ('EDA of votes participated in the data:')
display(df.votes.describe())

UR_x_votes = df.users_rating*df.votes
the_mean_user_rating = UR_x_votes.sum()/df.votes.sum()
R = df.users_rating
C = the_mean_user_rating
v = df.votes
m = df.votes.quantile(0.75)
df_75 = df[df.votes >= m]
df_75['w_rating'] = (v/(v + m)) * R + (m/(v + m)) * C
df_75 = df_75.sort_values(by = 'w_rating', ascending= False).reset_index(drop=True)
df_75.head()
# Out:
# EDA of votes participated in the data:
# count      1272.000000
# mean        459.427673
# std        6288.883170
# min           5.000000
# 25%          12.000000
# 50%          27.000000
# 75%          76.000000
# max      187222.000000
# Name: votes, dtype: float64
#   movie_id                                     title  year  \
# 0   100137                         A Man Called Ahok  2018
# 1   100173  Jelita Sejuba: Mencintai Kesatria Negara  2018
# 2   100228                                 Yowis Ben  2018
# 3   100450                                The Raid 2  2014
# 4   100023                           27 Steps of May  2019
#
#                                          description      genre rating  \
# 0  Depicts the life of the titular former governo...  Biography    13+
# 1  Without dating, Jaka immediately proposes for ...      Drama    13+
# 2  Bayu falls in love with a girl and decided to ...     Comedy    13+
# 3  Only a short time after the first raid, Rama g...     Action      R
# 4  Following a horrible experience, May has isola...      Drama    17+
#
#    users_rating   votes   languages         directors  \
# 0           8.7    4235  Indonesian      Putrama Tuta
# 1           9.1     240  Indonesian        Ray Nayoan
# 2           8.4    3080  Indonesian      Fajar Nugros
# 3           8.0  112091  Indonesian      Gareth Evans
# 4           8.2     280  Indonesian  Ravi L. Bharwani
#
#                                               actors     runtime     decade  \
# 0  [Daniel Mananta, Kin Wah Chew, Eric Febrian, D...  102.000000  2010-2020
# 1  [Putri Marino, Wafda Saifan Lubis, Alvaro Mald...   97.550943  2010-2020
# 2  [Bayu Skak, Cut Meyriska, Brandon Salim, Joshu...   97.550943  2010-2020
# 3  [Iko Uwais, Arifin Putra, Tio Pakusadewo, Oka ...  150.000000  2010-2020
# 4  [Raihaanun Soeriaatmadja, Lukman Sardi, Ario B...  112.000000  2010-2020
#
#    w_rating
# 0  8.671094
# 1  8.609446
# 2  8.367739
# 3  7.999363
# 4  7.956699

# %% [markdown]
# ### Top 5 Indonesian Movies are:<br>
# - A Man Called Ahok (2018) by Putrama Tuta  [8.67]
# - Jelita Sejuba: Mencintai Kesatria Negara (2018) by Ray Nayoan  [8.61]
# - Yowis Ben (2018) by Fajar Nugros  [8.37]
# - The Raid 2 (2014) by Gareth Evans  [8.00]
# - 27 Steps of May (2019) by Ravi L. Bharwani  [7.96]

# %% [markdown]
# ## Indonesian Actors and Directors who played and made the most movies
# We calculate actors who played the most movies in two parts of calculation:
# - Actors and directors who participated in the most movies
# - Actors and directors who participated in the most successful movies by the weighted rating calculated.

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list])

# %%
actors_1d = to_1D(df.actors)
actors_1d = actors_1d[actors_1d != 'nan']
most5_act = actors_1d.value_counts().head(10).reset_index()
most5_act.columns = ['actor', 'sum']
most5_dir = df['directors'].value_counts().head(10).reset_index()
most5_dir.columns = ['directors','sum'] 

display(most5_act)
display(most5_dir)


actors_1d = to_1D(df_75.actors)
actors_1d = actors_1d[actors_1d != 'nan']
most5_act = actors_1d.value_counts().head(10).reset_index()
most5_act.columns = ['actor', 'sum']
most5_dir = df_75['directors'].value_counts().head(10).reset_index()
most5_dir.columns = ['directors','sum']

display(most5_act)
display(most5_dir)
# Out:
#              actor  sum
# 0     Lukman Sardi   57
# 1    Reza Rahadian   47
# 2   Verdi Solaiman   45
# 3   Jajang C. Noer   45
# 4   Tio Pakusadewo   41
# 5       Dwi Sasono   36
# 6     Ray Sahetapy   36
# 7      Barry Prima   35
# 8   Henky Solaiman   35
# 9  Slamet Rahardjo   35
#                directors  sum
# 0       Nayato Fio Nuala   61
# 1        Rizal Mantovani   34
# 2       Hanung Bramantyo   31
# 3                 Arizal   28
# 4  Sisworo Gautama Putra   23
# 5             Monty Tiwa   23
# 6          Findo Purwono   21
# 7          Jose Poernomo   21
# 8         Rudy Soedjarwo   21
# 9          Rako Prijanto   20
#                actor  sum
# 0      Reza Rahadian   31
# 1       Lukman Sardi   30
# 2          Ario Bayu   20
# 3     Tio Pakusadewo   19
# 4     Donny Alamsyah   19
# 5     Verdi Solaiman   18
# 6     Jajang C. Noer   17
# 7     Yayu A.W. Unru   16
# 8  Abimana Aryasatya   16
# 9   Hannah Al Rashid   14
#                directors  sum
# 0       Hanung Bramantyo   18
# 1        Rizal Mantovani   16
# 2              Riri Riza   10
# 3  Angga Dwimas Sasongko    8
# 4             Monty Tiwa    7
# 5            Upi Avianto    7
# 6            Awi Suryadi    7
# 7             Joko Anwar    7
# 8         Rudy Soedjarwo    7
# 9           Anggy Umbara    7

# %%
mask = df_75.directors=='Hanung Bramantyo'
df_75[mask]['w_rating'].mean()
# Out:
# 6.849183036863551

# %% [markdown]
# - Actor who played the most in Indonesian filmatography is Lukman Sardi with 57 Movies in total.
# - Directors who mad the movies in Indonesian Filmatography is Nayato Fio Naula with 61 Movies in total.
#
# - The highest rated movie actor out of 5 of the most contributed actors in Indonesian Filmatography is Reza Rahadian with an average rating of 6.99
# - The highest rated director out of 5 of the most contributed directors in Indonesian Filmatography is Hanung Bramantyo with movie rating of 6.85 in average.

# %%
y = pd.Series(most5_act.actor).reset_index(drop = True)
means = []
for i in range(len(y)):
    mask = df_75.actors.apply(lambda x: y[i] in x)
    m    = df_75[mask].w_rating.mean()
    means.append(m)
most5_act['w_rating_average']= means
most5_act
# Out:
#                actor  sum  w_rating_average
# 0      Reza Rahadian   31          6.990846
# 1       Lukman Sardi   30          6.859277
# 2          Ario Bayu   20          6.798045
# 3     Tio Pakusadewo   19          6.793970
# 4     Donny Alamsyah   19          6.979555
# 5     Verdi Solaiman   18          6.528430
# 6     Jajang C. Noer   17          7.033288
# 7     Yayu A.W. Unru   16          7.227131
# 8  Abimana Aryasatya   16          6.488232
# 9   Hannah Al Rashid   14          6.160578

# %%
UR_x_votes = most5_act['w_rating_average'] * most5_act['sum']
the_mean_user_rating = UR_x_votes.sum()/most5_act['sum'].sum()
R = most5_act['w_rating_average']
C = the_mean_user_rating
v = most5_act['sum']
m = 14
most5_act['w_rating_t'] = (v/(v + m)) * R + (m/(v + m)) * C

# %%
mask = df.actors.apply(lambda x : 'Yayu A.W. Unru' in x)
df[mask]
# Out:
#     movie_id                                     title  year  \
# 64    100065                         Koki-Koki Cilik 2  2019
# 74    100075                           Love for Sale 2  2019
# 80    100081                                  MatiAnak  2019
# 96    100097                           Ratu Ilmu Hitam  2019
# 136   100137                         A Man Called Ahok  2018
# 172   100173  Jelita Sejuba: Mencintai Kesatria Negara  2018
# 173   100174             Kafir: Bersekutu dengan Setan  2018
# 188   100189                             Menunggu Pagi  2018
# 211   100212                      Something in Between  2018
# 256   100257         Marlina the Murderer in Four Acts  2017
# 265   100266                                 Night Bus  2017
# 270   100271                                   Posesif  2017
# 282   100283        Surat Cinta Untuk Starla the Movie  2017
# 303   100304                                  Bangkit!  2016
# 313   100314                                  Headshot  2016
# 329   100330                             Midnight Show  2016
# 361   100362                                       #66  2015
# 382   100383                              Kapan Kawin?  2015
# 447   100448                               Tabula Rasa  2014
# 623   100624                                Lovely Man  2011
# 628   100629                            Mortal Enemies  2011
# 800   100801                              Sang Pemimpi  2009
#
#                                            description      genre     rating  \
# 64   Cooking Camp is opened again. The little chefs...      Drama         SU
# 74   Tired of matchmaking by his mother, Ican bring...      Drama        17+
# 80   Since a new kid arrives at an orphanage, weird...     Horror        17+
# 96   Families were terrorized at the orphanage. Som...     Horror        17+
# 136  Depicts the life of the titular former governo...  Biography        13+
# 172  Without dating, Jaka immediately proposes for ...      Drama        13+
# 173  A family is being haunted by some strange happ...      Drama        17+
# 270  [Putri Marino, Adipati Dolken, Griselda Agatha...  102.000000  2010-2020
# 282  [Jefri Nichol, Caitlin Halderman, Salshabilla ...   90.000000  2010-2020
# 303  [Putri Ayudya, Vino G. Bastian, Donny Damara, ...   97.550943  2010-2020
# 313  [Iko Uwais, Chelsea Islan, Sunny Pang, Very Tr...  118.000000  2010-2020
# 329  [Gandhi Fernando, Acha Septriasa, Ganindra Bim...  100.000000  2010-2020
# 361  [Ari Riski Ananda, Erwin Bagindo, Fandy Christ...  116.000000  2010-2020
# 382  [Adinia Wirasti, Reza Rahadian, Adi Kurdi, Iva...   97.550943  2010-2020
# 447  [Jimmy Kobogau, Dewi Irawan, Yayu A.W. Unru, O...  107.000000  2010-2020
# 623  [Donny Damara, Raihaanun Soeriaatmadja, Yayu A...   76.000000  2010-2020
# 628  [Robin Shou, Verdy Bhawanta, Yayu A.W. Unru, M...  103.000000  2010-2020
# 800  [Lukman Sardi, Rendy Ahmad, Vikri Septiawan, A...  120.000000  2000-2010

# %%
display(most5_act.sort_values(['sum'], ascending=False))
display(most5_act.sort_values(['w_rating_t'], ascending=False))
# Out:
#                actor  sum  w_rating_average  w_rating_t
# 0      Reza Rahadian   31          6.990846    6.936020
# 1       Lukman Sardi   30          6.859277    6.845068
# 2          Ario Bayu   20          6.798045    6.804870
# 3     Tio Pakusadewo   19          6.793970    6.802731
# 4     Donny Alamsyah   19          6.979555    6.909582
# 5     Verdi Solaiman   18          6.528430    6.653638
# 6     Jajang C. Noer   17          7.033288    6.934535
# 7     Yayu A.W. Unru   16          7.227131    7.034626
# 8  Abimana Aryasatya   16          6.488232    6.640546
# 9   Hannah Al Rashid   14          6.160578    6.487599
#                actor  sum  w_rating_average  w_rating_t
# 7     Yayu A.W. Unru   16          7.227131    7.034626
# 0      Reza Rahadian   31          6.990846    6.936020
# 6     Jajang C. Noer   17          7.033288    6.934535
# 4     Donny Alamsyah   19          6.979555    6.909582
# 1       Lukman Sardi   30          6.859277    6.845068
# 2          Ario Bayu   20          6.798045    6.804870
# 3     Tio Pakusadewo   19          6.793970    6.802731
# 5     Verdi Solaiman   18          6.528430    6.653638
# 8  Abimana Aryasatya   16          6.488232    6.640546
# 9   Hannah Al Rashid   14          6.160578    6.487599

# %%
df_n = pd.DataFrame()
for i in range ( len(most5_act)) :
    y = most5_act.loc[i,'actor']
    mask = df_75['actors'].apply(lambda x: y in x)
    df_a = df_75[mask]
    df_a['actor_name']= y
    df_n = df_n.append(df_a)
df_n = df_n.reset_index(drop = True)
df_n
# Out:
#     movie_id                                    title  year  \
# 0     100056                                Imperfect  2019
# 1     100252                                  Kartini  2017
# 2     100535                          Habibie & Ainun  2012
# 3     100508             The Sinking of Van Der Wijck  2013
# 4     100336                             Rudy Habibie  2016
# ..       ...                                      ...   ...
# 195   100299  Warkop DKI Reborn: Jangkrik Boss Part 2  2017
# 196   100043                                 DreadOut  2019
# 197   100305       Bulan Terbelah di Langit Amerika 2  2016
# 198   100171                            Jailangkung 2  2018
# 199   100249                              Jailangkung  2017
#
#                                            description      genre rating  \
# 0    Being born fat and has dark skins, it feels li...     Comedy    13+
# 1    This movie follows the story of the Indonesian...  Biography     SU
# 2    This movie is based on the memoir written by t...  Biography    13+
# 3    Adapted from a classic novel with the same tit...      Drama    13+
# 4    This movie follows the story of the 3rd Presid...  Biography    13+
# ..                                                 ...        ...    ...
# 195  Dono, Kasino, and Indro's adventure continues....  Adventure    13+
# 196  Six friends want to become popular by recordin...  Adventure    17+
# 197  When Hanum and Rangga decided to return to Vie...  Adventure    13+
# 198  A girl watched an old videotape owned by his f...     Horror    13+
# 199  The daughter who tries to figure out the myste...     Horror    13+
#
#      users_rating  votes   languages         directors  \
# 0             7.8    624  Indonesian    Ernest Prakasa
# 1             7.7    336  Indonesian  Hanung Bramantyo
# 2             7.6   1783  Indonesian      Faozan Rizal
# 3             7.6   1023       Dutch      Sunil Soraya
# 4             7.5    644  Indonesian  Hanung Bramantyo
# ..            ...    ...         ...               ...
# 195           5.5    404  Indonesian      Anggy Umbara
# 196           5.3    390  Indonesian     Kimo Stamboel
# 197           4.4    153  Indonesian   Rizal Mantovani
# 198           4.0    109  Indonesian   Rizal Mantovani
# 199           3.7    221  Indonesian   Rizal Mantovani
#
#                                                 actors     runtime     decade  \
# 0    [Jessica Mila, Reza Rahadian, Yasmin Napper, K...  113.000000  2010-2020
# 1    [Dian Sastrowardoyo, Reza Rahadian, Adinia Wir...  122.000000  2010-2020
# 2    [Reza Rahadian, Bunga Citra Lestari, Tio Pakus...  120.000000  2010-2020
# 3    [Herjunot Ali, Pevita Pearce, Reza Rahadian, R...  164.000000  2010-2020
# 4    [Reza Rahadian, Chelsea Islan, Ernest Prakasa,...   97.550943  2010-2020
# ..                                                 ...         ...        ...
# 195  [Abimana Aryasatya, Vino G. Bastian, Tora Sudi...   97.550943  2010-2020
# 196  [Caitlin Halderman, Jefri Nichol, Marsha Aruan...   97.000000  2010-2020
# 197  [Acha Septriasa, Abimana Aryasatya, Nino Ferna...  100.000000  2010-2020
# 198  [Amanda Rawles, Jefri Nichol, Hannah Al Rashid...   83.000000  2010-2020
# 199  [Amanda Rawles, Jefri Nichol, Hannah Al Rashid...   86.000000  2010-2020
#
#      w_rating        actor_name
# 0    7.719693     Reza Rahadian
# 1    7.582002     Reza Rahadian
# 2    7.577937     Reza Rahadian
# 3    7.562680     Reza Rahadian
# 4    7.453590     Reza Rahadian
# ..        ...               ...
# 195  5.747052  Hannah Al Rashid
# 196  5.587092  Hannah Al Rashid
# 197  5.282904  Hannah Al Rashid
# 198  5.257216  Hannah Al Rashid
# 199  4.559882  Hannah Al Rashid
#
# [200 rows x 15 columns]

# %%
df_g                = df_n.groupby(['actor_name','year']).size().reset_index()
df_g ['percentage'] = df_n.groupby(['actor_name','year']).size().apply(lambda x: 100*x/ df_n.groupby(['actor_name','year']).size().sum()).values
df_g.columns        = ['actor_name','year','counts','percentage']
df_g
# Out:
#             actor_name  year  counts  percentage
# 0    Abimana Aryasatya  2009       1         0.5
# 1    Abimana Aryasatya  2011       1         0.5
# 2    Abimana Aryasatya  2012       1         0.5
# 3    Abimana Aryasatya  2013       3         1.5
# 4    Abimana Aryasatya  2015       3         1.5
# ..                 ...   ...     ...         ...
# 97      Yayu A.W. Unru  2015       1         0.5
# 98      Yayu A.W. Unru  2016       1         0.5
# 99      Yayu A.W. Unru  2017       4         2.0
# 100     Yayu A.W. Unru  2018       4         2.0
# 101     Yayu A.W. Unru  2019       2         1.0
#
# [102 rows x 4 columns]

# %%
fig = px.bar(df_g, 
            x = 'year',
            y = 'counts',
            color='actor_name',
            text=df_g['counts'].apply(lambda x: '{0:9.0f}'.format(x)),
            title= 'Best 5 Indonesian Actors best on weighted rating of movies')
fig.show()

# %%
df_g                = df_n.groupby(['actor_name','year']).size().reset_index()
df_g['w_rating']    = df_n.groupby(['actor_name','year'])['w_rating'].mean().reset_index()['w_rating']
df_g.columns = ['actor_name','year', 'counts', 'w_rating']

fig = px.bar(df_g,
            x = 'year',
            y = 'counts',
            color= 'actor_name',
            text = df_g['w_rating'].apply(lambda x: '{0:9.2f}'.format(x)))
fig.show()

# %%
df_n = pd.DataFrame()
for i in range ( len(most5_dir.head())) :
    y = most5_dir.loc[i,'directors']
    mask = df_75['directors']==y
    df_a = df_75[mask]
    df_a['directors']= y
    df_n = df_n.append(df_a)
df_n = df_n.reset_index(drop = True)
df_n
# Out:
#    movie_id                                   title  year  \
# 0    100252                                 Kartini  2017
# 1    100336                            Rudy Habibie  2016
# 2    100964                   Catatan Akhir Sekolah  2005
# 3    100947                                  Jomblo  2006
# 4    100893                          Verses of Love  2008
# 5    100286             Surga Yang Tak Dirindukan 2  2017
# 6    100654                             Tanda Tanya  2011
# 7    100048                       Habibie & Ainun 3  2019
# 8    100500             Soekarno: Indonesia Merdeka  2013
# 9    100559                           Perahu Kertas  2012
# 10   100213  Sultan Agung: Tahta, Perjuangan, Cinta  2018
# 11   100725                           Sang Pencerah  2010
# 12   100560                         Perahu Kertas 2  2012
# 13   100786              Perempuan Berkalung Sorban  2009
# 14   100124                   This Earth of Mankind  2019
# 15   100905                             Get Married  2007
# 16   100754                           Get Married 2  2009
# 17   100152                    Benyamin Biang Kerok  2018
# 18   100515                                    5 cm  2012
# 19   100031                           Antologi Rasa  2019
# 20   100164                    Eiffel I'm in Love 2  2018
# 21   100312                                Firegate  2016
# 22   101013                           The Uninvited  2001
# 23   100447                               Supernova  2014
# 24   100368        Bulan Terbelah di Langit Amerika  2015
# 25   100957                            The Chanting  2006
# 26   100422                      Cherrybelle: Crush  2014
# 27   100909                            Kuntilanak 2  2007
# 28   100855                            Kuntilanak 3  2008
# 29   100305      Bulan Terbelah di Langit Amerika 2  2016
# 30   100171                           Jailangkung 2  2018
# 31   100182                              Kuntilanak  2018
# 32   100249                             Jailangkung  2017
# 33   100741                    Air Terjun Pengantin  2009
# 34   100856                          Laskar Pelangi  2008
# 35   101016                     Petualangan Sherina  2000
# 36   100181                        Kulari ke Pantai  2018
# 37   100966                                     Gie  2005
# 38   100359                   What's Up with Love 2  2016
# 39   100033                                   Bebas  2019
# 40   100896                  3 Hari Untuk Selamanya  2007
# 41   100311                          Emma' (Mother)  2016
# 42   101005                          Eliana, Eliana  2002
# 43   100801                            Sang Pemimpi  2009
# 44   100454                        We Are Moluccans  2014
# 45   100013      Nanti Kita Cerita Tentang Hari Ini  2020
# 46   100685                       Hari Untuk Amanda  2010
# 47   100243             Filosofi Kopi 2: Ben & Jody  2017
# 48   100227                        Wiro Sableng 212  2018
# 49   100345                        Surat dari Praha  2016
# 50   100236                                Bukaan 8  2017
# 51   100376                           Filosofi Kopi  2015
# 52   100200                                  Rompis  2018
# 53   100338                     Sabtu Bersama Bapak  2016
# 54   100580                               Test Pack  2012
# 55   100491                       Operation Wedding  2013
# 56   100769                                 Keramat  2009
# 57   100077                          Mahasiswi Baru  2019
# 58   100093                       Pocong the Origin  2019
#
#                                           description      genre rating  \
# 0   This movie follows the story of the Indonesian...  Biography     SU
# 1   This movie follows the story of the 3rd Presid...  Biography    13+
# 2   A journey of three students for making a short...     Comedy    NaN
# 3   Four college best friends with their funny lif...     Comedy    NaN
# 4   A man who try to get through a complicated rel...      Drama    17+
# 5   Sequel to the 2015 film 'Surga Yang Tak Dirind...      Drama    13+
# 6   A story of interconnecting lives in modern day...      Drama    NaN
# 7   This movie follows the story of Hasri Ainun Be...  Biography    13+
# 8   This movie follows the life of Soekarno, the f...  Biography    NaN
# 9   Tidal relationship between two human beings, K...      Drama    NaN
# 10  The story about Sultan Agung of Mataram, how h...     Action    13+
# 11  The journey of an Indonesian national hero nam...  Biography    NaN
# 12  The sequel to the "Perahu Kertas" movie follow...      Drama    NaN
# 13  The story of a woman sacrifice and struggle, a...      Drama    17+
# 14  A native Javanese boy and a mixed-Dutch girl f...      Drama    17+
# 15  Mae (Nirina Zubir) and her friends have big ob...     Comedy    NaN
# 16  After four years of marriage, Mae and Rendy ha...     Comedy    NaN
# 17  Knowing that their headquarter and residential...     Comedy    17+
# 18  Five best friends try to find out what true fr...  Adventure    NaN
# 19  Keara (Carissa Perusset) loves Ruly (Refal Had...      Drama    17+
# 20  14 years passed. Tita who was a freshman in hi...      Drama    13+
# 21  The oldest pyramid in the world is found in In...  Adventure    NaN
# 22  Four young people spend their time looking int...     Horror    NaN
# 23  Two Indonesian students in the U.S. are brough...      Drama    NaN
# 24  A husband and wife, Hanum and Rangga, are tryi...  Adventure    17+
# 25  A young college student moves to a new boardin...     Horror    NaN
# 26  A girl group band in Indonesia must find their...     Comedy    NaN
# 27  A young college student has recently moved out...     Horror    NaN
# 28  A group of youngsters is on a mission to find ...     Horror      D
# 29  When Hanum and Rangga decided to return to Vie...  Adventure    13+
# 30  A girl watched an old videotape owned by his f...     Horror    13+
# 31  Five youngsters discover that an antique mirro...     Comedy  TV-14
# 32  The daughter who tries to figure out the myste...     Horror    13+
# 33  A woman and her lover go on vacation with thei...     Horror    NaN
# 34  In the 1970s, a group of 10 students struggles...  Adventure     SU
# 35  Adventure of a little girl who just moved to a...  Adventure    NaN
# 36  Two girls in their early teens embark on a roa...  Adventure     SU
# 37  Soe Hok Gie is an activist who lived in the si...  Biography    NaN
# 38  14 years after their budding romance in high s...      Drama    13+
# 39  A group of five girls and one boy becomes best...     Comedy    13+
# 40  The three days trip that changes everything. I...     Comedy    NaN
# 41  Athirah's life is shattered when another woman...      Drama    NaN
# 42  After three years of separation, Bunda pays he...      Drama    NaN
# 43  This movie is an adaptation from a popular nov...  Adventure    NaN
# 44  Five years conflict, thousands casualties, a f...  Biography    NaN
# 45  Three siblings live in happy-looking families,...      Drama    13+
# 46  Amanda (Fanny Fabriana), a woman in her mid-20...      Drama    NaN
# 47  Two years after Ben & Jody decided to sell the...  Adventure    13+
# 48  Indonesia, the 16th century, Wiro Sableng, a d...     Action    13+
# 49  A girl named Larasati (Julie Estelle), trying ...      Drama      R
# 50  Story of a married couple, Alam and Mia, who a...     Comedy    NaN
# 51  A coffee shop struggling to pay their debts, w...      Drama    NaN
# 52  After graduating from high school, Roman (Arba...      Drama    13+
# 53  It's a story about a young man looking for a l...      Drama    NaN
# 54  A couple who have been married 7 years set on ...     Comedy    NaN
# 55  A retired navy commander and overprotective si...     Comedy    NaN
# 56  A behind-the-scenes story of a group of filmma...     Horror      D
# 57  At her old age, Lastri (Widyawati) is eager to...     Comedy    13+
# 58  Ananta, a cold-blooded killer has been execute...  Adventure    13+
#
#     users_rating  votes   languages              directors  \
# 0            7.7    336  Indonesian       Hanung Bramantyo
# 1            7.5    644  Indonesian       Hanung Bramantyo
# 2            7.4    447  Indonesian       Hanung Bramantyo
# 3            7.2    317  Indonesian       Hanung Bramantyo
# 4            7.1    981  Indonesian       Hanung Bramantyo
# 5            7.1    359  Indonesian       Hanung Bramantyo
# 6            7.1    188  Indonesian       Hanung Bramantyo
# 7            7.0    133  Indonesian       Hanung Bramantyo
# 8            7.0    428  Indonesian       Hanung Bramantyo
# 9            7.0    519  Indonesian       Hanung Bramantyo
# 10           6.9    140  Indonesian       Hanung Bramantyo
# 11           6.8    209  Indonesian       Hanung Bramantyo
# 12           6.8    235  Indonesian       Hanung Bramantyo
# 13           6.7    120  Indonesian       Hanung Bramantyo
# 14           6.6    514  Indonesian       Hanung Bramantyo
# 15           6.5    216  Indonesian       Hanung Bramantyo
# 16           6.1     76  Indonesian       Hanung Bramantyo
# 17           2.9    213  Indonesian       Hanung Bramantyo
# 18           7.2   1709  Indonesian        Rizal Mantovani
# 19           7.2     98  Indonesian        Rizal Mantovani
# 20           6.8    329  Indonesian        Rizal Mantovani
# 21           6.5     98  Indonesian        Rizal Mantovani
# 22           6.6    326  Indonesian        Rizal Mantovani
# 23           6.4    289  Indonesian        Rizal Mantovani
# 24           6.0    213  Indonesian        Rizal Mantovani
# 25           6.1    403  Indonesian        Rizal Mantovani
# 26           5.6    111  Indonesian        Rizal Mantovani
# 27           5.7    155  Indonesian        Rizal Mantovani
# 28           5.3    169  Indonesian        Rizal Mantovani
# 29           4.4    153  Indonesian        Rizal Mantovani
# 30           4.0    109  Indonesian        Rizal Mantovani
# 31           4.8    493  Indonesian        Rizal Mantovani
# 32           3.7    221  Indonesian        Rizal Mantovani
# 33           3.5    190  Indonesian        Rizal Mantovani
# 34           7.8   2045  Indonesian              Riri Riza
# 35           7.8    640  Indonesian              Riri Riza
# 36           7.8    201  Indonesian              Riri Riza
# 37           7.6    840  Indonesian              Riri Riza
# 38           7.4   1650  Indonesian              Riri Riza
# 39           7.3    358  Indonesian              Riri Riza
# 40           7.1    305  Indonesian              Riri Riza
# 41           7.1    109  Indonesian              Riri Riza
# 58  [Nadya Arina, Samuel Rizal, Della Dartyan, Sur...   90.000000  2010-2020
#
#     w_rating
# 0   7.582002
# 1   7.453590
# 2   7.350640
# 3   7.172990
# 4   7.097148
# 5   7.093069
# 6   7.088579
# 7   7.021938
# 8   7.009097
# 9   7.007706
# 10  6.956412
# 11  6.869421
# 12  6.863617
# 13  6.839719
# 14  6.659297
# 15  6.645839
# 16  6.580164
# 17  3.994066
# 18  7.194053
# 19  7.138994
# 20  6.848852
# 21  6.744741
# 22  6.687027
# 23  6.537493
# 24  6.278841
# 25  6.252369
# 26  6.193503
# 27  6.147554
# 28  5.846061
# 29  5.282904
# 30  5.257216
# 31  5.101907
# 32  4.559882
# 33  4.517237
# 34  7.773496
# 35  7.721487
# 36  7.597058
# 37  7.555224
# 38  7.385043
# 39  7.258030
# 40  7.092087
# 41  7.083703
# 42  6.895120
# 43  6.846227
# 44  7.820110
# 45  7.455683
# 46  7.352922
# 47  7.254118
# 48  7.192434
# 49  7.168595
# 50  7.140365
# 51  7.095566
# 52  7.655498
# 53  7.405873
# 54  7.085643
# 55  6.900431
# 56  6.857348
# 57  6.472630
# 58  6.451156

# %%
df_g                = df_n.groupby(['directors','year']).size().reset_index()
df_g ['percentage'] = df_n.groupby(['directors','year']).size().apply(lambda x: 100*x/ df_n.groupby(['directors','year']).size().sum()).values
df_g.columns        = ['directors','year','counts','percentage']
df_g.head()
# Out:
#                directors  year  counts  percentage
# 0  Angga Dwimas Sasongko  2010       1    1.694915
# 1  Angga Dwimas Sasongko  2014       1    1.694915
# 2  Angga Dwimas Sasongko  2015       1    1.694915
# 3  Angga Dwimas Sasongko  2016       1    1.694915
# 4  Angga Dwimas Sasongko  2017       2    3.389831

# %%
fig = px.bar(df_g, 
            x = 'year',
            y = 'counts',
            color='directors',
            text=df_g['counts'].apply(lambda x: '{0:9.0f}'.format(x)),
            title= 'Best 5 Indonesian Directors based on weighted rating of movies')
fig.show()

# %%
df_g                = df_n.groupby(['directors','year']).size().reset_index()
df_g['w_rating']    = df_n.groupby(['directors','year'])['w_rating'].mean().reset_index()['w_rating']
df_g.columns = ['directors','year', 'counts', 'w_rating']

fig = px.bar(df_g,
            x = 'year',
            y = 'counts',
            color= 'directors',
            text = df_g['w_rating'].apply(lambda x: '{0:9.2f}'.format(x)))
fig.show()

# %%
mask = df.directors=='Angga Dwimas Sasongko'
df[df.directors=='Angga Dwimas Sasongko'][df['year']==2020]
# Out:
#    movie_id                               title  year  \
# 12   100013  Nanti Kita Cerita Tentang Hari Ini  2020
#
#                                           description  genre rating  \
# 12  Three siblings live in happy-looking families,...  Drama    13+
#
#     users_rating  votes   languages              directors  \
# 12           7.5    678  Indonesian  Angga Dwimas Sasongko
#
#                                                actors  runtime     decade
# 12  [Rio Dewanto, Sheila Dara Aisha, Rachel Amanda...    121.0  2010-2020

# %% [markdown]
# - Movie with the highest w_rating shows the people's hype for a film on a certain year. For example, in 2000 people are hyping about Riri Riza's Petualangan Sherina. In 2005, Its Riri Riza's Gie and Hanung Bramantyo's Catatan Akhir Sekolah
# - In 2016 people are into movies the most, because of the year's many and high average w_rating of the movies
